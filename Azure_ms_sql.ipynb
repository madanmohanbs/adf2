# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argcomplete                   1.12.3
# argon2-cffi                   21.1.0
# arviz                         0.11.4
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.2
# ...

# %%
pip install pymssql
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 4.9 MB/s
# ...

# %%
server = 'madan-sqldb.database.windows.net'
user= 'madan'
password= 'Sinthiya@123'

# %%
import pymssql
import pandas as pd
import ipywidgets as iw

# %%
conn = pymssql.connect(server, user, password, "octave-db")
cursor = conn.cursor(as_dict=True)
cursor

# %%
cursor.execute(f'SELECT * FROM SalesLT.Customer')
for row in cursor:
    print(row)

# %%
id=1
sql=f'SELECT * FROM SalesLT.Customer where customerId ={id}'
print(sql)
# Out:
# SELECT * FROM SalesLT.Customer where customerId =1

# %%
cursor.close()

# %%
cursor.execute(sql)
for row in cursor:
    print(row)
# Out:
# {'CustomerID': 1, 'NameStyle': False, 'Title': 'Mr.', 'FirstName': 'Orlando', 'MiddleName': 'N.', 'LastName': 'Gee', 'Suffix': None, 'CompanyName': 'A Bike Store', 'SalesPerson': 'adventure-works\\pamela0', 'EmailAddress': 'orlando0@adventure-works.com', 'Phone': '245-555-0173', 'PasswordHash': 'L/Rlwxzp4w7RWmEgXX+/A7cXaePEPcp+KwQhl2fJL7w=', 'PasswordSalt': '1KjXYs4=', 'rowguid': UUID('3f5ae95e-b87d-4aed-95b4-c3797afcb74f'), 'ModifiedDate': datetime.datetime(2005, 8, 1, 0, 0)}

# %%
cursor.execute(sql)
data =[ row for row in cursor]
print(data)
# Out:
# [{'CustomerID': 1, 'NameStyle': False, 'Title': 'Mr.', 'FirstName': 'Orlando', 'MiddleName': 'N.', 'LastName': 'Gee', 'Suffix': None, 'CompanyName': 'A Bike Store', 'SalesPerson': 'adventure-works\\pamela0', 'EmailAddress': 'orlando0@adventure-works.com', 'Phone': '245-555-0173', 'PasswordHash': 'L/Rlwxzp4w7RWmEgXX+/A7cXaePEPcp+KwQhl2fJL7w=', 'PasswordSalt': '1KjXYs4=', 'rowguid': UUID('3f5ae95e-b87d-4aed-95b4-c3797afcb74f'), 'ModifiedDate': datetime.datetime(2005, 8, 1, 0, 0)}]

# %%
for row in cursor.:
    print(row)

# %%
df = pd.DataFrame(data)
df
# Out:
#    CustomerID  NameStyle  ...                               rowguid ModifiedDate
# 0           1      False  ...  3f5ae95e-b87d-4aed-95b4-c3797afcb74f   2005-08-01
#
# [1 rows x 15 columns]

# %%
for key, value in data[0].items():
  print(key,value)
# Out:
# CustomerID 1
# NameStyle False
# Title Mr.
# FirstName Orlando
# MiddleName N.
# LastName Gee
# Suffix None
# CompanyName A Bike Store
# SalesPerson adventure-works\pamela0
# EmailAddress orlando0@adventure-works.com
# Phone 245-555-0173
# PasswordHash L/Rlwxzp4w7RWmEgXX+/A7cXaePEPcp+KwQhl2fJL7w=
# PasswordSalt 1KjXYs4=
# rowguid 3f5ae95e-b87d-4aed-95b4-c3797afcb74f
# ModifiedDate 2005-08-01 00:00:00

# %%
rows=[]

# %%
for key1, value1 in data[0].items():
 label = iw.Label(value=key1)
 text = iw.Text(value=str(value1))
 stripe=iw.HBox([label,text])
 rows.append(stripe)

box = iw.VBox(rows)

# %%
display(box)

# %%
conn = pymssql.connect(server, user, password, "testdb")
cursor = conn.cursor(as_dict=True)

cursor.execute('SELECT * FROM persons WHERE salesrep=%s', 'John Doe')
for row in cursor:
    print("ID=%d, Name=%s" % (row['id'], row['name']))

conn.close()
